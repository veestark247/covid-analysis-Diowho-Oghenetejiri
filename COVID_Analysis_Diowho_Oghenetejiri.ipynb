# %% [markdown]
# COVID-19 Data Analysis
#
# Name: Diowho Oghenetejiri **
# Course: Data Science and Analytics**
# Project: From Notebook to Insight**
# Dataset: CDC COVID-19 Case Surveillance Public Use Data

# %%
import pandas as pd

url = "https://data.cdc.gov/resource/vbim-akqf.csv?$limit=12500000"
df = pd.read_csv(url)

print(df.shape)
df.head()
# Out:
# (12500000, 12)
#       cdc_case_earliest_dt            cdc_report_dt              pos_spec_dt  \
# 0  2023-12-20T00:00:00.000                      NaN                      NaN
# 1  2022-06-09T00:00:00.000                      NaN                      NaN
# 2  2022-01-20T00:00:00.000  2022-01-20T00:00:00.000                      NaN
# 3  2022-05-09T00:00:00.000  2022-05-09T00:00:00.000                      NaN
# 4  2022-06-09T00:00:00.000  2022-06-10T00:00:00.000  2022-06-09T00:00:00.000
#
#                   onset_dt             current_status     sex      age_group  \
# 0                      NaN  Laboratory-confirmed case  Female  20 - 29 Years
# 1                      NaN  Laboratory-confirmed case  Female  20 - 29 Years
# 2                      NaN  Laboratory-confirmed case  Female  20 - 29 Years
# 3  2022-05-09T00:00:00.000  Laboratory-confirmed case  Female  20 - 29 Years
# 4  2022-06-09T00:00:00.000  Laboratory-confirmed case  Female  20 - 29 Years
#
# ...
